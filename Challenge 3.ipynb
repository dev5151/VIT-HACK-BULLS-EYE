# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
import math

# %%
# %matplotlib inline

# %%
company = pd.read_csv("ADANIPORTSALLN.csv")

# %%
company.columns
# Out:
# Index(['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price',
#        'Low Price', 'Last Price', 'Close Price', 'Average Price',
#        'Total Traded Quantity', 'Turnover', 'No. of Trades', 'Deliverable Qty',
#        '% Dly Qt to Traded Qty'],
#       dtype='object')

# %%
company
# Out:
#          Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0    ADANIPORTS     EQ  ...         1456435                   48.49
# 1    ADANIPORTS     EQ  ...         1502442                   59.91
# 2    ADANIPORTS     EQ  ...         1833961                   56.51
# 3    ADANIPORTS     EQ  ...         2154296                   62.99
# 4    ADANIPORTS     EQ  ...         1536874                   51.59
# 5    ADANIPORTS     EQ  ...         1551332                   55.90
# 6    ADANIPORTS     EQ  ...          514295                   34.03
# 7    ADANIPORTS     EQ  ...         1028102                   42.38
# 8    ADANIPORTS     EQ  ...         1017134                   43.04
# 9    ADANIPORTS     EQ  ...          932721                   51.09
# 10   ADANIPORTS     EQ  ...          948222                   51.76
# 11   ADANIPORTS     EQ  ...          935780                   50.35
# 12   ADANIPORTS     EQ  ...         1555085                   64.72
# 13   ADANIPORTS     EQ  ...         1851621                   71.88
# 14   ADANIPORTS     EQ  ...         1055138                   49.86
# 15   ADANIPORTS     EQ  ...         3103057                   61.42
# 16   ADANIPORTS     EQ  ...         4083453                   63.28
# 17   ADANIPORTS     EQ  ...         2624640                   70.97
# 18   ADANIPORTS     EQ  ...         3381897                   82.37
# 19   ADANIPORTS     EQ  ...         3586471                   68.47
# 20   ADANIPORTS     EQ  ...         2873835                   66.54
# 21   ADANIPORTS     EQ  ...         3164319                   72.39
# 22   ADANIPORTS     EQ  ...         3057349                   69.28
# 23   ADANIPORTS     EQ  ...         2152065                   69.08
# 24   ADANIPORTS     EQ  ...         1438674                   47.80
# 25   ADANIPORTS     EQ  ...         2244647                   59.29
# 26   ADANIPORTS     EQ  ...         1010609                   47.90
# 27   ADANIPORTS     EQ  ...         2239095                   60.95
# 28   ADANIPORTS     EQ  ...         1165609                   55.92
# 29   ADANIPORTS     EQ  ...         1214041                   65.50
# ..          ...    ...  ...             ...                     ...
# 465  ADANIPORTS     EQ  ...          490305                   24.24
# 466  ADANIPORTS     EQ  ...          553194                   31.92
# 467  ADANIPORTS     EQ  ...         1099524                   39.01
# 468  ADANIPORTS     EQ  ...         1329007                   51.08
# 469  ADANIPORTS     EQ  ...          799469                   37.86
# 470  ADANIPORTS     EQ  ...          462815                   27.25
# 471  ADANIPORTS     EQ  ...          313479                   24.11
# 472  ADANIPORTS     EQ  ...          463190                   24.45
# 473  ADANIPORTS     EQ  ...          476512                   24.54
# 474  ADANIPORTS     EQ  ...         1274810                   44.95
# 475  ADANIPORTS     EQ  ...         1757153                   37.01
# 476  ADANIPORTS     EQ  ...          738965                   24.64
# 477  ADANIPORTS     EQ  ...         1252491                   46.36
# 478  ADANIPORTS     EQ  ...          559921                   29.64
# 479  ADANIPORTS     EQ  ...          676447                   29.26
# 480  ADANIPORTS     EQ  ...          838299                   34.50
# 481  ADANIPORTS     EQ  ...          612696                   35.62
# 482  ADANIPORTS     EQ  ...         1054765                   34.82
# 483  ADANIPORTS     EQ  ...          756571                   31.10
# 484  ADANIPORTS     EQ  ...         1848265                   49.70
# 485  ADANIPORTS     EQ  ...          683772                   20.00
# 486  ADANIPORTS     EQ  ...         1080055                   31.79
# 487  ADANIPORTS     EQ  ...          614627                   27.65
# 488  ADANIPORTS     EQ  ...         1045652                   40.58
# 489  ADANIPORTS     EQ  ...         2254085                   50.01
# 490  ADANIPORTS     EQ  ...         2593908                   58.51
# 491  ADANIPORTS     EQ  ...          729231                   33.88
# 492  ADANIPORTS     EQ  ...          516740                   29.23
# 493  ADANIPORTS     EQ  ...          472606                   32.38
# 494  ADANIPORTS     EQ  ...          658426                   30.33
#
# [495 rows x 15 columns]

# %% [markdown]
# # Data Preprocessing

# %%
#Two types of trading Intraday and delivery
#Intraday holds position only for a day
#Delivery is used to hold position for more than a day
# eg 100 shares-- shares taken for delivery is 40 and rest intraday 
#so 40 deliverable and traded 100 % is 40%
#If the delivery % is high that means that market is optimistic about the stock and the chances of it grow is high.

# %%
#Visualizing the closing data

company[["Close Price"]].plot()
plt.title("Closing price")
plt.show()

# %%
#Cummulative Return
df = company.cumsum()
#plt.legend
df.plot(legend=False)
plt.title("cummulative returns")
# Out:
# Text(0.5, 1.0, 'cummulative returns')

# %%
plt.figure(figsize=(12,12))
lag_plot(company['Open Price'],lag=3)
plt.title("Company timeseries plot")
# Out:
# Text(0.5, 1.0, 'Company timeseries plot')

# %%
plt.figure(figsize=(10,10))
lag_plot(company['Close Price'],lag=3)
plt.title("Company timeseries plot")
# Out:
# Text(0.5, 1.0, 'Company timeseries plot')

# %%
train, test = company[0:int(len(company)*0.9)], company[int(len(company)*0.9):]
train.head()
# Out:
#        Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  ADANIPORTS     EQ  ...         1456435                   48.49
# 1  ADANIPORTS     EQ  ...         1502442                   59.91
# 2  ADANIPORTS     EQ  ...         1833961                   56.51
# 3  ADANIPORTS     EQ  ...         2154296                   62.99
# 4  ADANIPORTS     EQ  ...         1536874                   51.59
#
# [5 rows x 15 columns]

# %%
train
# Out:
#          Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0    ADANIPORTS     EQ  ...         1456435                   48.49
# 1    ADANIPORTS     EQ  ...         1502442                   59.91
# 2    ADANIPORTS     EQ  ...         1833961                   56.51
# 3    ADANIPORTS     EQ  ...         2154296                   62.99
# 4    ADANIPORTS     EQ  ...         1536874                   51.59
# 5    ADANIPORTS     EQ  ...         1551332                   55.90
# 6    ADANIPORTS     EQ  ...          514295                   34.03
# 7    ADANIPORTS     EQ  ...         1028102                   42.38
# 8    ADANIPORTS     EQ  ...         1017134                   43.04
# 9    ADANIPORTS     EQ  ...          932721                   51.09
# 10   ADANIPORTS     EQ  ...          948222                   51.76
# 11   ADANIPORTS     EQ  ...          935780                   50.35
# 12   ADANIPORTS     EQ  ...         1555085                   64.72
# 13   ADANIPORTS     EQ  ...         1851621                   71.88
# 14   ADANIPORTS     EQ  ...         1055138                   49.86
# 15   ADANIPORTS     EQ  ...         3103057                   61.42
# 16   ADANIPORTS     EQ  ...         4083453                   63.28
# 17   ADANIPORTS     EQ  ...         2624640                   70.97
# 18   ADANIPORTS     EQ  ...         3381897                   82.37
# 19   ADANIPORTS     EQ  ...         3586471                   68.47
# 20   ADANIPORTS     EQ  ...         2873835                   66.54
# 21   ADANIPORTS     EQ  ...         3164319                   72.39
# 22   ADANIPORTS     EQ  ...         3057349                   69.28
# 23   ADANIPORTS     EQ  ...         2152065                   69.08
# 24   ADANIPORTS     EQ  ...         1438674                   47.80
# 25   ADANIPORTS     EQ  ...         2244647                   59.29
# 26   ADANIPORTS     EQ  ...         1010609                   47.90
# 27   ADANIPORTS     EQ  ...         2239095                   60.95
# 28   ADANIPORTS     EQ  ...         1165609                   55.92
# 29   ADANIPORTS     EQ  ...         1214041                   65.50
# ..          ...    ...  ...             ...                     ...
# 415  ADANIPORTS     EQ  ...          716120                   42.59
# 416  ADANIPORTS     EQ  ...         1548307                   61.88
# 417  ADANIPORTS     EQ  ...          960389                   44.89
# 418  ADANIPORTS     EQ  ...          771097                   41.38
# 419  ADANIPORTS     EQ  ...          752175                   45.64
# 420  ADANIPORTS     EQ  ...          589474                   36.19
# 421  ADANIPORTS     EQ  ...          614190                   36.38
# 422  ADANIPORTS     EQ  ...          302972                   23.03
# 423  ADANIPORTS     EQ  ...          901474                   29.75
# 424  ADANIPORTS     EQ  ...          475166                   31.25
# 425  ADANIPORTS     EQ  ...         1417246                   46.46
# 426  ADANIPORTS     EQ  ...          923445                   36.95
# 427  ADANIPORTS     EQ  ...         1455711                   46.11
# 428  ADANIPORTS     EQ  ...         1577810                   51.57
# 429  ADANIPORTS     EQ  ...         4385195                   39.96
# 430  ADANIPORTS     EQ  ...         2453039                   26.91
# 431  ADANIPORTS     EQ  ...         1282250                   28.22
# 432  ADANIPORTS     EQ  ...         7368903                   32.01
# 433  ADANIPORTS     EQ  ...         3328325                   35.89
# 434  ADANIPORTS     EQ  ...         1306385                   25.67
# 435  ADANIPORTS     EQ  ...         7993630                   43.69
# 436  ADANIPORTS     EQ  ...          602631                   24.00
# 437  ADANIPORTS     EQ  ...         3139799                   56.09
# 438  ADANIPORTS     EQ  ...         1170858                   27.76
# 439  ADANIPORTS     EQ  ...         1317070                   34.19
# 440  ADANIPORTS     EQ  ...         2243034                   29.19
# 441  ADANIPORTS     EQ  ...         1887537                   38.93
# 442  ADANIPORTS     EQ  ...          650342                   24.55
# 443  ADANIPORTS     EQ  ...          665361                   28.02
# 444  ADANIPORTS     EQ  ...          586294                   34.34
#
# [445 rows x 15 columns]

# %%
test
# Out:
#          Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 445  ADANIPORTS     EQ  ...          611047                   26.23
# 446  ADANIPORTS     EQ  ...         1512951                   51.71
# 447  ADANIPORTS     EQ  ...         1204654                   43.88
# 448  ADANIPORTS     EQ  ...         1376709                   49.33
# 449  ADANIPORTS     EQ  ...         1786201                   50.21
# 450  ADANIPORTS     EQ  ...         2615869                   44.05
# 451  ADANIPORTS     EQ  ...         2670501                   31.85
# 452  ADANIPORTS     EQ  ...         2014166                   42.76
# 453  ADANIPORTS     EQ  ...          931971                   36.08
# 454  ADANIPORTS     EQ  ...          905615                   43.14
# 455  ADANIPORTS     EQ  ...          738771                   22.20
# 456  ADANIPORTS     EQ  ...         4441882                   50.24
# 457  ADANIPORTS     EQ  ...          540507                   25.15
# 458  ADANIPORTS     EQ  ...          313765                   21.53
# 459  ADANIPORTS     EQ  ...          414283                   24.78
# 460  ADANIPORTS     EQ  ...          807188                   31.75
# 461  ADANIPORTS     EQ  ...          221164                   20.08
# 462  ADANIPORTS     EQ  ...          376232                   22.53
# 463  ADANIPORTS     EQ  ...          253874                   15.40
# 464  ADANIPORTS     EQ  ...          365554                   18.72
# 465  ADANIPORTS     EQ  ...          490305                   24.24
# 466  ADANIPORTS     EQ  ...          553194                   31.92
# 467  ADANIPORTS     EQ  ...         1099524                   39.01
# 468  ADANIPORTS     EQ  ...         1329007                   51.08
# 469  ADANIPORTS     EQ  ...          799469                   37.86
# 470  ADANIPORTS     EQ  ...          462815                   27.25
# 471  ADANIPORTS     EQ  ...          313479                   24.11
# 472  ADANIPORTS     EQ  ...          463190                   24.45
# 473  ADANIPORTS     EQ  ...          476512                   24.54
# 474  ADANIPORTS     EQ  ...         1274810                   44.95
# 475  ADANIPORTS     EQ  ...         1757153                   37.01
# 476  ADANIPORTS     EQ  ...          738965                   24.64
# 477  ADANIPORTS     EQ  ...         1252491                   46.36
# 478  ADANIPORTS     EQ  ...          559921                   29.64
# 479  ADANIPORTS     EQ  ...          676447                   29.26
# 480  ADANIPORTS     EQ  ...          838299                   34.50
# 481  ADANIPORTS     EQ  ...          612696                   35.62
# 482  ADANIPORTS     EQ  ...         1054765                   34.82
# 483  ADANIPORTS     EQ  ...          756571                   31.10
# 484  ADANIPORTS     EQ  ...         1848265                   49.70
# 485  ADANIPORTS     EQ  ...          683772                   20.00
# 486  ADANIPORTS     EQ  ...         1080055                   31.79
# 487  ADANIPORTS     EQ  ...          614627                   27.65
# 488  ADANIPORTS     EQ  ...         1045652                   40.58
# 489  ADANIPORTS     EQ  ...         2254085                   50.01
# 490  ADANIPORTS     EQ  ...         2593908                   58.51
# 491  ADANIPORTS     EQ  ...          729231                   33.88
# 492  ADANIPORTS     EQ  ...          516740                   29.23
# 493  ADANIPORTS     EQ  ...          472606                   32.38
# 494  ADANIPORTS     EQ  ...          658426                   30.33
#
# [50 rows x 15 columns]

# %%
plt.figure(figsize=(10,10))
plt.title('Company Prices')
plt.plot(company['Open Price'], 'red', label='Training Data')
plt.plot(test['Open Price'], 'green', label='Testing Data')
#plt.plot(company['Close Price'], 'yellow', label='Training Data')
#plt.plot(test['Close Price'], 'blue', label='Testing Data')
plt.legend()

# %%
plt.figure(figsize=(10,10))
plt.ylabel('Prices')
plt.plot(company['Close Price'], 'yellow', label='Training Data')
plt.plot(test['Close Price'], 'blue', label='Testing Data')

# %%
#def smape_kun(y_true, y_pred):
#   return np.mean((np.abs(y_pred - y_true) * 200/ (np.abs(y_pred) + np.abs(y_true))))

def return_rmse(y_true,y_pred):
    rmse = math.sqrt(mean_squared_error(y_true,y_pred))
    print("The root mean squared error is {}.".format(rmse))

# %%
train_model_close = train['Close Price'].values
test_model_close = test['Close Price'].values

# %%
#model training
#the order 3,1,0 is for the lag, difference order and moving time average
#fir disp=0 saves us from seeing all the debugging options
prev_close = [x for x in train_model_close]
hist = [x for x in train_model_close]
print(type(prev_close))
pred = []
for t in range(len(test_model_close)):
  model = ARIMA(hist, order=(3,1,0))
  model_fit = model.fit(disp=0)
  output = model_fit.forecast()
  yhat = output[0]
  pred.append(yhat)
  obs =  test_model_close[t]
  hist.append(obs)
  
  
error = return_rmse(test_model_close, pred)
print(error)
# Out:
# <class 'list'>
# The root mean squared error is 6.340814269409937.
# None

# %%
pred
# Out:
# [array([426.38010001]),
#  array([425.22585907]),
#  array([424.9932907]),
#  array([426.35452262]),
#  array([423.43697467]),
#  array([421.52011627]),
#  array([409.47265408]),
#  array([401.5337655]),
#  array([402.00449249]),
#  array([405.76288278]),
#  array([405.86634064]),
#  array([413.81519014]),
#  array([407.92760855]),
#  array([409.26848048]),
#  array([413.2789977]),
#  array([414.04912036]),
#  array([414.82879103]),
#  array([414.98591945]),
#  array([403.98435859]),
#  array([397.928419]),
#  array([404.33663539]),
#  array([405.39861153]),
#  array([411.83760745]),
#  array([415.36398094]),
#  array([409.77868253]),
#  array([416.51805261]),
#  array([417.64048581]),
#  array([412.82282199]),
#  array([406.2443635]),
#  array([406.94218239]),
#  array([400.89362362]),
#  array([382.68385565]),
#  array([379.86259667]),
#  array([381.82232901]),
#  array([374.76197139]),
#  array([373.1890352]),
#  array([377.14975949]),
#  array([371.94726237]),
#  array([374.67149838]),
#  array([368.91798015]),
#  array([375.52971693]),
#  array([373.21526527]),
#  array([373.4299666]),
#  array([376.38563474]),
#  array([362.51902866]),
#  array([358.40359042]),
#  array([357.56549243]),
#  array([357.29680194]),
#  array([355.19200065]),
#  array([351.03977301])]

# %%
plt.figure(figsize=(12,7))
plt.plot(company['Close Price'], 'green', color='blue', label='Training Data')
plt.plot(test.index, pred, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test.index, test['Close Price'], color='red', label='Actual Price')
plt.title('Company Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
#plt.xticks(np.arange(0,1857, 300), df['Date'][0:1857:300])
plt.legend()

# %% [markdown]
# # LSTM SECTION

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

# %%
lcompany = pd.read_csv("ADANIPORTSALLN.csv")

# %%
lcompany
# Out:
#          Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0    ADANIPORTS     EQ  ...         1456435                   48.49
# 1    ADANIPORTS     EQ  ...         1502442                   59.91
# 2    ADANIPORTS     EQ  ...         1833961                   56.51
# 3    ADANIPORTS     EQ  ...         2154296                   62.99
# 4    ADANIPORTS     EQ  ...         1536874                   51.59
# 5    ADANIPORTS     EQ  ...         1551332                   55.90
# 6    ADANIPORTS     EQ  ...          514295                   34.03
# 7    ADANIPORTS     EQ  ...         1028102                   42.38
# 8    ADANIPORTS     EQ  ...         1017134                   43.04
# 9    ADANIPORTS     EQ  ...          932721                   51.09
# 10   ADANIPORTS     EQ  ...          948222                   51.76
# 11   ADANIPORTS     EQ  ...          935780                   50.35
# 12   ADANIPORTS     EQ  ...         1555085                   64.72
# 13   ADANIPORTS     EQ  ...         1851621                   71.88
# 14   ADANIPORTS     EQ  ...         1055138                   49.86
# 15   ADANIPORTS     EQ  ...         3103057                   61.42
# 16   ADANIPORTS     EQ  ...         4083453                   63.28
# 17   ADANIPORTS     EQ  ...         2624640                   70.97
# 18   ADANIPORTS     EQ  ...         3381897                   82.37
# 19   ADANIPORTS     EQ  ...         3586471                   68.47
# 20   ADANIPORTS     EQ  ...         2873835                   66.54
# 21   ADANIPORTS     EQ  ...         3164319                   72.39
# 22   ADANIPORTS     EQ  ...         3057349                   69.28
# 23   ADANIPORTS     EQ  ...         2152065                   69.08
# 24   ADANIPORTS     EQ  ...         1438674                   47.80
# 25   ADANIPORTS     EQ  ...         2244647                   59.29
# 26   ADANIPORTS     EQ  ...         1010609                   47.90
# 27   ADANIPORTS     EQ  ...         2239095                   60.95
# 28   ADANIPORTS     EQ  ...         1165609                   55.92
# 29   ADANIPORTS     EQ  ...         1214041                   65.50
# ..          ...    ...  ...             ...                     ...
# 465  ADANIPORTS     EQ  ...          490305                   24.24
# 466  ADANIPORTS     EQ  ...          553194                   31.92
# 467  ADANIPORTS     EQ  ...         1099524                   39.01
# 468  ADANIPORTS     EQ  ...         1329007                   51.08
# 469  ADANIPORTS     EQ  ...          799469                   37.86
# 470  ADANIPORTS     EQ  ...          462815                   27.25
# 471  ADANIPORTS     EQ  ...          313479                   24.11
# 472  ADANIPORTS     EQ  ...          463190                   24.45
# 473  ADANIPORTS     EQ  ...          476512                   24.54
# 474  ADANIPORTS     EQ  ...         1274810                   44.95
# 475  ADANIPORTS     EQ  ...         1757153                   37.01
# 476  ADANIPORTS     EQ  ...          738965                   24.64
# 477  ADANIPORTS     EQ  ...         1252491                   46.36
# 478  ADANIPORTS     EQ  ...          559921                   29.64
# 479  ADANIPORTS     EQ  ...          676447                   29.26
# 480  ADANIPORTS     EQ  ...          838299                   34.50
# 481  ADANIPORTS     EQ  ...          612696                   35.62
# 482  ADANIPORTS     EQ  ...         1054765                   34.82
# 483  ADANIPORTS     EQ  ...          756571                   31.10
# 484  ADANIPORTS     EQ  ...         1848265                   49.70
# 485  ADANIPORTS     EQ  ...          683772                   20.00
# 486  ADANIPORTS     EQ  ...         1080055                   31.79
# 487  ADANIPORTS     EQ  ...          614627                   27.65
# 488  ADANIPORTS     EQ  ...         1045652                   40.58
# 489  ADANIPORTS     EQ  ...         2254085                   50.01
# 490  ADANIPORTS     EQ  ...         2593908                   58.51
# 491  ADANIPORTS     EQ  ...          729231                   33.88
# 492  ADANIPORTS     EQ  ...          516740                   29.23
# 493  ADANIPORTS     EQ  ...          472606                   32.38
# 494  ADANIPORTS     EQ  ...          658426                   30.33
#
# [495 rows x 15 columns]

# %%
lclose= lcompany["Close Price"]

# %%
lclose.shape
# Out:
# (495,)

# %%
ltrain=lclose.iloc[:396].values

# %%
ltest=lclose.iloc[396:].values

# %%
ltrain.reshape(396,1)
# Out:
# array([[385.  ],
#        [380.05],
#        [387.5 ],
#        [383.3 ],
#        [389.75],
#        [392.95],
#        [394.9 ],
#        [384.85],
#        [390.3 ],
#        [385.05],
#        [387.7 ],
#        [385.9 ],
#        [385.35],
#        [389.05],
#        [390.  ],
#        [403.1 ],
#        [405.15],
#        [404.7 ],
#        [406.9 ],
#        [409.7 ],
#        [410.2 ],
#        [401.2 ],
#        [388.65],
#        [390.55],
#        [372.55],
#        [372.05],
#        [376.75],
#        [383.7 ],
#        [387.65],
#        [385.9 ],
#        [389.25],
#        [393.7 ],
#        [396.85],
#        [396.95],
#        [403.7 ],
#        [408.2 ],
#        [406.8 ],
#        [406.85],
#        [406.9 ],
#        [401.4 ],
#        [407.05],
#        [406.2 ],
#        [415.45],
#        [414.3 ],
#        [432.05],
#        [429.8 ],
#        [430.35],
#        [433.1 ],
#        [437.25],
#        [434.85],
#        [437.55],
#        [431.55],
#        [429.7 ],
#        [433.4 ],
#        [432.05],
#        [413.35],
#        [410.75],
#        [407.1 ],
#        [397.2 ],
#        [400.95],
#        [398.6 ],
#        [400.8 ],
#        [414.5 ],
#        [407.1 ],
#        [404.6 ],
#        [399.5 ],
#        [396.95],
#        [403.45],
#        [398.  ],
#        [386.75],
#        [388.15],
#        [388.85],
#        [385.75],
#        [389.7 ],
#        [393.4 ],
#        [391.75],
#        [402.5 ],
#        [394.  ],
#        [395.1 ],
#        [401.35],
#        [404.6 ],
#        [405.8 ],
#        [404.4 ],
#        [402.3 ],
#        [402.15],
#        [404.55],
#        [404.2 ],
#        [398.7 ],
#        [405.65],
#        [399.65],
#        [397.4 ],
#        [407.65],
#        [409.85],
#        [423.8 ],
#        [422.9 ],
#        [421.1 ],
#        [423.45],
#        [425.5 ],
#        [423.3 ],
#        [420.6 ],
#        [423.55],
#        [433.4 ],
#        [416.25],
#        [433.45],
#        [438.05],
#        [438.4 ],
#        [448.75],
#        [436.5 ],
#        [436.65],
#        [428.25],
#        [428.85],
#        [428.75],
#        [417.95],
#        [408.2 ],
#        [404.8 ],
#        [407.  ],
#        [405.1 ],
#        [399.  ],
#        [403.35],
#        [413.  ],
#        [411.7 ],
#        [405.45],
#        [393.85],
#        [394.9 ],
#        [395.6 ],
#        [404.  ],
#        [406.5 ],
#        [415.05],
#        [410.45],
#        [408.35],
#        [406.1 ],
#        [403.95],
#        [405.25],
#        [376.95],
#        [387.95],
#        [377.9 ],
#        [386.6 ],
#        [385.2 ],
#        [382.1 ],
#        [382.15],
#        [370.5 ],
#        [364.3 ],
#        [370.  ],
#        [363.7 ],
#        [358.25],
#        [362.4 ],
#        [365.15],
#        [365.5 ],
#        [354.1 ],
#        [369.7 ],
#        [366.4 ],
#        [367.8 ],
#        [375.95],
#        [379.3 ],
#        [377.35],
#        [387.25],
#        [377.9 ],
#        [372.35],
#        [383.1 ],
#        [387.5 ],
#        [383.4 ],
#        [384.95],
#        [386.55],
#        [381.15],
#        [386.35],
#        [392.25],
#        [391.9 ],
#        [397.1 ],
#        [402.45],
#        [407.3 ],
#        [401.1 ],
#        [397.  ],
#        [408.25],
#        [412.4 ],
#        [412.8 ],
#        [413.35],
#        [410.8 ],
#        [412.7 ],
#        [409.95],
#        [409.15],
#        [403.1 ],
#        [397.9 ],
#        [389.5 ],
#        [383.7 ],
#        [379.75],
#        [374.25],
#        [371.25],
#        [379.9 ],
#        [378.9 ],
#        [377.85],
#        [374.4 ],
#        [392.15],
#        [387.6 ],
#        [378.55],
#        [373.6 ],
#        [375.8 ],
#        [380.05],
#        [380.5 ],
#        [382.3 ],
#        [388.9 ],
#        [382.85],
#        [374.45],
#        [372.95],
#        [370.55],
#        [362.45],
#        [365.65],
#        [366.9 ],
#        [365.8 ],
#        [361.15],
#        [362.9 ],
#        [361.1 ],
#        [361.8 ],
#        [373.15],
#        [362.8 ],
#        [362.75],
#        [359.95],
#        [361.9 ],
#        [365.75],
#        [366.95],
#        [370.45],
#        [373.5 ],
#        [369.35],
#        [370.4 ],
#        [360.05],
#        [366.7 ],
#        [364.05],
#        [369.6 ],
#        [370.05],
#        [383.75],
#        [392.6 ],
#        [398.75],
#        [399.3 ],
#        [394.65],
#        [390.8 ],
#        [399.75],
#        [399.  ],
#        [399.15],
#        [399.55],
#        [397.35],
#        [372.3 ],
#        [374.6 ],
#        [378.  ],
#        [379.3 ],
#        [377.15],
#        [373.15],
#        [370.3 ],
#        [374.1 ],
#        [378.25],
#        [377.95],
#        [384.5 ],
#        [376.75],
#        [378.65],
#        [386.95],
#        [385.9 ],
#        [383.75],
#        [383.15],
#        [384.45],
#        [373.75],
#        [379.2 ],
#        [384.8 ],
#        [377.45],
#        [371.95],
#        [364.65],
#        [376.05],
#        [380.1 ],
#        [380.8 ],
#        [379.55],
#        [372.4 ],
#        [361.75],
#        [345.85],
#        [337.95],
#        [338.55],
#        [335.25],
#        [328.9 ],
#        [330.35],
#        [329.75],
#        [317.05],
#        [301.8 ],
#        [304.35],
#        [318.75],
#        [327.1 ],
#        [313.5 ],
#        [323.15],
#        [321.25],
#        [333.35],
#        [313.9 ],
#        [315.35],
#        [315.4 ],
#        [319.  ],
#        [314.15],
#        [305.6 ],
#        [304.1 ],
#        [326.4 ],
#        [322.6 ],
#        [318.85],
#        [318.3 ],
#        [333.6 ],
#        [329.55],
#        [325.6 ],
#        [326.2 ],
#        [337.6 ],
#        [328.65],
#        [334.1 ],
#        [332.  ],
#        [346.2 ],
#        [347.45],
#        [350.55],
#        [355.25],
#        [361.25],
#        [368.15],
#        [369.05],
#        [369.05],
#        [365.4 ],
#        [369.8 ],
#        [365.65],
#        [375.65],
#        [373.8 ],
#        [374.75],
#        [363.95],
#        [373.45],
#        [359.15],
#        [355.75],
#        [374.45],
#        [371.05],
#        [368.6 ],
#        [371.4 ],
#        [372.9 ],
#        [375.85],
#        [375.15],
#        [361.1 ],
#        [361.1 ],
#        [376.55],
#        [384.  ],
#        [387.4 ],
#        [387.7 ],
#        [389.  ],
#        [381.3 ],
#        [378.1 ],
#        [382.15],
#        [381.65],
#        [378.75],
#        [377.3 ],
#        [380.25],
#        [377.15],
#        [374.45],
#        [385.15],
#        [389.3 ],
#        [394.5 ],
#        [399.3 ],
#        [396.2 ],
#        [390.6 ],
#        [385.2 ],
#        [380.95],
#        [373.85],
#        [326.1 ],
#        [349.25],
#        [338.15],
#        [338.65],
#        [338.45],
#        [335.65],
#        [339.8 ],
#        [330.35],
#        [332.35],
#        [331.5 ],
#        [328.8 ],
#        [326.8 ],
#        [341.65],
#        [349.1 ],
#        [350.15],
#        [347.3 ],
#        [339.55],
#        [354.75],
#        [355.75],
#        [354.3 ],
#        [324.55],
#        [323.5 ],
#        [325.25],
#        [325.85],
#        [333.2 ],
#        [339.25],
#        [337.05],
#        [340.9 ],
#        [342.15],
#        [351.3 ],
#        [361.05],
#        [367.15],
#        [366.  ],
#        [367.1 ],
#        [369.  ],
#        [365.75],
#        [360.6 ],
#        [360.75],
#        [360.75],
#        [361.35],
#        [368.6 ],
#        [366.3 ]])

# %%
ltest.reshape(99,1)
# Out:
# array([[381.3 ],
#        [378.15],
#        [383.05],
#        [379.7 ],
#        [382.  ],
#        [380.2 ],
#        [387.15],
#        [379.9 ],
#        [380.7 ],
#        [383.45],
#        [379.45],
#        [385.65],
#        [387.05],
#        [395.65],
#        [390.55],
#        [391.05],
#        [390.9 ],
#        [391.75],
#        [389.25],
#        [391.75],
#        [392.8 ],
#        [395.3 ],
#        [387.25],
#        [379.8 ],
#        [371.9 ],
#        [369.8 ],
#        [363.9 ],
#        [372.55],
#        [364.75],
#        [370.55],
#        [360.15],
#        [371.5 ],
#        [367.1 ],
#        [400.1 ],
#        [387.6 ],
#        [385.95],
#        [407.55],
#        [410.25],
#        [412.4 ],
#        [412.65],
#        [406.55],
#        [409.3 ],
#        [416.4 ],
#        [424.75],
#        [425.55],
#        [426.3 ],
#        [425.2 ],
#        [425.75],
#        [426.3 ],
#        [424.95],
#        [424.95],
#        [426.4 ],
#        [422.85],
#        [421.4 ],
#        [407.7 ],
#        [401.2 ],
#        [402.  ],
#        [406.  ],
#        [405.65],
#        [414.95],
#        [406.5 ],
#        [410.2 ],
#        [413.25],
#        [414.05],
#        [414.9 ],
#        [414.9 ],
#        [402.45],
#        [397.8 ],
#        [405.  ],
#        [405.  ],
#        [412.9 ],
#        [415.3 ],
#        [409.1 ],
#        [417.75],
#        [417.05],
#        [412.4 ],
#        [405.5 ],
#        [407.2 ],
#        [399.75],
#        [380.8 ],
#        [380.35],
#        [381.65],
#        [373.85],
#        [373.45],
#        [377.55],
#        [371.1 ],
#        [375.45],
#        [367.85],
#        [376.95],
#        [372.25],
#        [373.95],
#        [376.6 ],
#        [360.55],
#        [358.85],
#        [357.35],
#        [357.4 ],
#        [354.95],
#        [350.7 ],
#        [345.05]])

# %%
sc = MinMaxScaler(feature_range=(0,1))

# %%
ltrain_scaled = sc.fit_transform(ltrain.reshape(396,1))

# %%
X_train = []
y_train = []
for i in range(5,396):
    X_train.append(ltrain_scaled[i-5:i,0])
    y_train.append(ltrain_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train
# Out:
# array([[0.56617897, 0.53249405, 0.58319156, 0.55461041, 0.59850289],
#        [0.53249405, 0.58319156, 0.55461041, 0.59850289, 0.62027901],
#        [0.58319156, 0.55461041, 0.59850289, 0.62027901, 0.63354883],
#        ...,
#        [0.4572984 , 0.43518203, 0.4001361 , 0.40115686, 0.40115686],
#        [0.43518203, 0.4001361 , 0.40115686, 0.40115686, 0.40523988],
#        [0.4001361 , 0.40115686, 0.40115686, 0.40523988, 0.45457639]])

# %%
##
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
regressor = Sequential()
# First LSTM layer with Dropout regularisation
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))
# Second LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# Third LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# Fourth LSTM layer
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))
# The output layer
regressor.add(Dense(units=1))

regressor.compile(optimizer='rmsprop',loss='mean_squared_error')
# Fitting to the training set
regressor.fit(X_train,y_train,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.1150
# Epoch 2/50
# 391/391 [==============================] - 0s 712us/step - loss: 0.0203
# Epoch 3/50
# 391/391 [==============================] - 0s 720us/step - loss: 0.0166
# Epoch 4/50
# 391/391 [==============================] - 0s 760us/step - loss: 0.0187
# Epoch 5/50
# 391/391 [==============================] - 0s 767us/step - loss: 0.0141
# Epoch 6/50
# 391/391 [==============================] - 0s 723us/step - loss: 0.0168
# Epoch 7/50
# 391/391 [==============================] - 0s 717us/step - loss: 0.0124
# Epoch 8/50
# 391/391 [==============================] - 0s 770us/step - loss: 0.0204
# Epoch 9/50
# 391/391 [==============================] - 0s 727us/step - loss: 0.0130
# Epoch 10/50
# 391/391 [==============================] - 0s 739us/step - loss: 0.0153
# Epoch 11/50
# 391/391 [==============================] - 0s 808us/step - loss: 0.0149
# Epoch 12/50
# 391/391 [==============================] - 0s 798us/step - loss: 0.0142
# Epoch 13/50
# 391/391 [==============================] - 0s 807us/step - loss: 0.0167
# Epoch 14/50
# 391/391 [==============================] - 0s 771us/step - loss: 0.0127
# Epoch 15/50
# 391/391 [==============================] - 0s 764us/step - loss: 0.0152
# Epoch 16/50
# 391/391 [==============================] - 0s 787us/step - loss: 0.0119
# Epoch 17/50
# 391/391 [==============================] - 0s 794us/step - loss: 0.0149
# Epoch 18/50
# 391/391 [==============================] - 0s 797us/step - loss: 0.0112
# Epoch 19/50
# 391/391 [==============================] - 0s 786us/step - loss: 0.0142
# Epoch 20/50
# 391/391 [==============================] - 0s 782us/step - loss: 0.0121
# Epoch 21/50
# 391/391 [==============================] - 0s 777us/step - loss: 0.0145
# Epoch 22/50
# 391/391 [==============================] - 0s 771us/step - loss: 0.0131
# Epoch 23/50
# 391/391 [==============================] - 0s 801us/step - loss: 0.0119
# Epoch 24/50
# 391/391 [==============================] - 0s 750us/step - loss: 0.0129
# Epoch 25/50
# 391/391 [==============================] - 0s 807us/step - loss: 0.0118
# Epoch 26/50
# 391/391 [==============================] - 0s 812us/step - loss: 0.0124
# Epoch 27/50
# 391/391 [==============================] - 0s 749us/step - loss: 0.0108
# Epoch 28/50
# 391/391 [==============================] - 0s 720us/step - loss: 0.0135
# Epoch 29/50
# 391/391 [==============================] - 0s 780us/step - loss: 0.0108
# Epoch 30/50
# 391/391 [==============================] - 0s 718us/step - loss: 0.0123
# Epoch 31/50
# 391/391 [==============================] - 0s 765us/step - loss: 0.0110
# Epoch 32/50
# 391/391 [==============================] - 0s 783us/step - loss: 0.0123
# Epoch 33/50
# 391/391 [==============================] - 0s 710us/step - loss: 0.0138
# Epoch 34/50
# 391/391 [==============================] - 0s 716us/step - loss: 0.0105
# Epoch 35/50
# 391/391 [==============================] - 0s 760us/step - loss: 0.0109
# Epoch 36/50
# 391/391 [==============================] - 0s 740us/step - loss: 0.0125
# Epoch 37/50
# 391/391 [==============================] - 0s 707us/step - loss: 0.0120
# Epoch 38/50
# 391/391 [==============================] - 0s 741us/step - loss: 0.0107
# Epoch 39/50
# 391/391 [==============================] - 0s 758us/step - loss: 0.0103
# Epoch 40/50
# 391/391 [==============================] - 0s 746us/step - loss: 0.0103
# Epoch 41/50
# 391/391 [==============================] - 0s 735us/step - loss: 0.0124
# Epoch 42/50
# 391/391 [==============================] - 0s 792us/step - loss: 0.0099
# Epoch 43/50
# 391/391 [==============================] - 0s 752us/step - loss: 0.0112
# Epoch 44/50
# 391/391 [==============================] - 0s 755us/step - loss: 0.0108
# Epoch 45/50
# 391/391 [==============================] - 0s 737us/step - loss: 0.0113
# Epoch 46/50
# 391/391 [==============================] - 0s 723us/step - loss: 0.0107
# Epoch 47/50
# 391/391 [==============================] - 0s 773us/step - loss: 0.0097
# Epoch 48/50
# 391/391 [==============================] - 0s 721us/step - loss: 0.0101
# Epoch 49/50
# 391/391 [==============================] - 0s 733us/step - loss: 0.0117
# Epoch 50/50
# 391/391 [==============================] - 0s 743us/step - loss: 0.0109

# %%
dataset_total = pd.concat((pd.Series(ltrain),pd.Series(ltest)),axis=0)
inputs = dataset_total[len(dataset_total)-len(ltest) - 5:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# %%
# Preparing X_test and predicting the prices
X_test = []
for i in range(5,99):
    X_test.append(inputs[i-5:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real Stock price')
    plt.plot(predicted, color='blue',label='Predicted Stock Price')
    plt.title('Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('Companies Stock Price')
    plt.legend()
    plt.show()
plot_predictions(ltest,predicted_stock_price)

# %%
def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    
return_rmse(ltest[:94],predicted_stock_price)
# Out:
# The root mean squared error is 11.667034900194658.
